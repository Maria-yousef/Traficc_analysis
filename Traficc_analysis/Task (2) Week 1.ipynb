# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
import pandas as pd
df= pd.read_csv('Task (2) Dataset.csv')
df
# Out:
#            City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0      Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1      Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2      Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3      Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4      Abudhabi  2023-07-07 12:01:30                 8         20       62.1
# ...         ...                  ...               ...        ...        ...
# 66634    Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635    Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636    Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637    Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638    Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
#        JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0             0.7                   13           59.611918       54.803617
# 1             1.7                    8           60.221387       56.118629
# 2             2.8                    6           59.161978       55.518834
# 3             5.5                    6           59.738138       56.413917
# 4             6.5                    5           58.958314       56.059246
# ...           ...                  ...                 ...             ...
# 66634        20.4                    8           63.926569       63.245473
# 66635        13.8                    5           59.182641       60.012955
# 66636         6.7                    1           57.746816       57.561438
# 66637         4.3                    0           56.535277       55.463218
# 66638         5.2                    0           56.126417       54.886055
#
# [66639 rows x 9 columns]

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df['Datetime'] = pd.to_datetime(df['Datetime'])
print(df.describe(include='all'))



plt.figure(figsize=(12, 6))
sns.lineplot(x='Datetime', y='TrafficIndexLive', hue='City', data=df)
plt.title('Traffic Index Live Over Time')
plt.show()
# Out:
#          City                       Datetime  TrafficIndexLive     JamsCount  \
# count   66639                          66639      66639.000000  66639.000000
# unique     11                            NaN               NaN           NaN
# top      Doha                            NaN               NaN           NaN
# freq     8692                            NaN               NaN           NaN
# mean      NaN  2023-07-21 19:21:11.079652864         14.043113     74.278531
# min       NaN            2022-12-16 11:01:30          0.000000      0.000000
# 25%       NaN            2023-05-04 19:01:15          3.000000      9.000000
# 50%       NaN            2023-08-11 02:16:30         10.000000     29.000000
# 75%       NaN            2023-10-13 05:01:30         21.000000     95.000000
# max       NaN            2023-12-15 08:46:30        138.000000   1359.000000
# std       NaN                            NaN         13.488906    107.452022
#
#            JamsDelay    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  \
# count   66639.000000  66639.000000         66639.000000        62772.000000
# unique           NaN           NaN                  NaN                 NaN
# top              NaN           NaN                  NaN                 NaN
# freq             NaN           NaN                  NaN                 NaN
# mean      288.353877     49.316135            13.981737           70.706601
# min         0.000000      0.000000             0.000000           49.381346
# 25%        27.700000      3.000000             3.000000           63.142591
# 50%        95.700000     12.200000            10.000000           68.894790
# 75%       336.600000     53.500000            21.000000           76.250975
# max      9989.400000   1173.900000           138.000000          120.140593
# std       470.013224     85.352525            13.454922           10.588384
#
#         TravelTimeLive
# count     62772.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean         70.048451
# min          46.723235
# 25%          60.712805
# 50%          68.247303
# 75%          77.043739
# max         134.484139
# std          11.966725

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])
df['Date'] = df['Datetime'].dt.date
plt.figure(figsize=(12, 6))
sns.histplot(df['TrafficIndexLive'], bins=20, kde=True)
plt.title('Distribution of Traffic Index Live')
plt.xlabel('Traffic Index Live')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
df.describe()
# Out:
#                             Datetime  TrafficIndexLive     JamsCount  \
# count                          66639      66639.000000  66639.000000
# mean   2023-07-21 19:21:11.079652864         14.043113     74.278531
# min              2022-12-16 11:01:30          0.000000      0.000000
# 25%              2023-05-04 19:01:15          3.000000      9.000000
# 50%              2023-08-11 02:16:30         10.000000     29.000000
# 75%              2023-10-13 05:01:30         21.000000     95.000000
# max              2023-12-15 08:46:30        138.000000   1359.000000
# std                              NaN         13.488906    107.452022
#
#           JamsDelay    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  \
# count  66639.000000  66639.000000         66639.000000        62772.000000
# mean     288.353877     49.316135            13.981737           70.706601
# min        0.000000      0.000000             0.000000           49.381346
# 25%       27.700000      3.000000             3.000000           63.142591
# 50%       95.700000     12.200000            10.000000           68.894790
# 75%      336.600000     53.500000            21.000000           76.250975
# max     9989.400000   1173.900000           138.000000          120.140593
# std      470.013224     85.352525            13.454922           10.588384
#
#        TravelTimeLive
# count    62772.000000
# mean        70.048451
# min         46.723235
# 25%         60.712805
# 50%         68.247303
# 75%         77.043739
# max        134.484139
# std         11.966725

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Datetime', y='TrafficIndexLive', hue='City', data=df)
plt.title('Traffic Index Live Over Time')
plt.xlabel('Datetime')
plt.ylabel('Traffic Index Live')
plt.legend(title='City')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
numerical_columns=df[['JamsCount', 'JamsDelay' ]]
correlation_matrix=numerical_columns.corr()
print(numerical_columns)
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True)
plt.title("Heat map")
plt.show()
# Out:
#        JamsCount  JamsDelay
# 0              4       15.6
# 1              7       20.5
# 2              8       25.0
# 3             11       30.6
# 4             20       62.1
# ...          ...        ...
# 66634         33      127.8
# 66635         27       87.0
# 66636         17       49.8
# 66637         16       61.3
# 66638         15       39.5
#
# [66639 rows x 2 columns]

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
#
